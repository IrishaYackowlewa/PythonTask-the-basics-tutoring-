# %% [markdown]
# ## Проектная работа. Прогназирование прогулов на работе.

# %%
import numpy as np

from sklearn import *

import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.linear_model import RidgeCV

# %%
data = pd.read_csv('Absenteeism_at_work_2.csv', delimiter=',')

# %%
data.tail(10)
# Out:
#      ID  Reason for absence  Year  Month of absence  Month and Year  \
# 727   9                   6     3                 7              42
# 728  34                  28     3                 7              42
# 729   9                   6     3                 7              42
# 730   6                  22     3                 7              42
# 731  34                  23     3                 7              42
# 732  10                  22     3                 7              42
# 733  28                  22     3                 7              42
# 734  13                  13     3                 7              42
# 735  11                  14     3                 7              42
# 736   1                  11     3                 7              42
#
#      Day of the week  Seasons  Transportation expense  \
# 727                2        1                     228
# 728                2        1                     118
# ...

# %%
data.head(11)
# Out:
#     ID  Reason for absence  Year  Month of absence  Month and Year  \
# 0   11                  26     0                 7               6
# 1   36                   0     0                 7               6
# 2    3                  23     0                 7               6
# 3    7                   7     0                 7               6
# 4   11                  23     0                 7               6
# 5    3                  23     0                 7               6
# 6   10                  22     0                 7               6
# 7   20                  23     0                 7               6
# 8   14                  19     0                 7               6
# 9    1                  22     0                 7               6
# 10  20                   1     0                 7               6
#
#     Day of the week  Seasons  Transportation expense  \
# 0                 3        1                     289
# ...

# %%
s = data.groupby('Month and Year')['Absenteeism time in hours'].sum()

# %%
fig, ax = plt.subplots(figsize=[20,10])
ax.plot(s,color='b')
plt.show()

# %%
s
# Out:
# Month and Year
# 6     129
# 7     140
# 8      88
# 9      74
# 10    161
# 11    177
# 12     60
# 13     87
# 14    281
# 15    194
# 16     91
# 17    191
# 18    137
# 19     72
# 20    163
# 21    176
# 22    205
# 23     69
# 24     74
# 25    106
# 26    127
# 27    174
# 28     75
# 29    122
# 30    204
# 31     76
# 32     41
# 33     99
# 34    107
# 35    168
# 36     88
# 37    101
# 38    357
# 39    114
# 40    234
# 41     98
# 42    264
# Name: Absenteeism time in hours, dtype: int64

# %%
groub = data.groupby(['Month and Year'])['Seasons'].min()

# %%
groub
# Out:
# Month and Year
# 6     1
# 7     1
# 8     4
# 9     4
# 10    4
# 11    2
# 12    2
# 13    2
# 14    3
# 15    3
# 16    3
# 17    1
# 18    1
# 19    1
# 20    4
# 21    4
# 22    4
# 23    2
# 24    2
# 25    2
# 26    3
# 27    3
# 28    3
# 29    1
# 30    1
# 31    1
# 32    4
# 33    4
# 34    4
# 35    2
# 36    2
# 37    2
# 38    3
# 39    3
# 40    3
# 41    1
# 42    1
# Name: Seasons, dtype: int64

# %%
X = np.zeros((s.shape[0]-3-1-1-1,5))
X[:,0] = s.values[2:-4] 
X[:,1] = s.values[1:-5]
X[:,2] = s.values[0:-6] 
X[:,3] = groub.values[2:-4] 
X[:,4] = groub.values[3:-3] 
print(X)
# Out:
# [[ 88. 140. 129.   4.   4.]
#  [ 74.  88. 140.   4.   4.]
#  [161.  74.  88.   4.   2.]
#  [177. 161.  74.   2.   2.]
#  [ 60. 177. 161.   2.   2.]
#  [ 87.  60. 177.   2.   3.]
#  [281.  87.  60.   3.   3.]
#  [194. 281.  87.   3.   3.]
#  [ 91. 194. 281.   3.   1.]
#  [191.  91. 194.   1.   1.]
#  [137. 191.  91.   1.   1.]
#  [ 72. 137. 191.   1.   4.]
#  [163.  72. 137.   4.   4.]
#  [176. 163.  72.   4.   4.]
#  [205. 176. 163.   4.   2.]
#  [ 69. 205. 176.   2.   2.]
#  [ 74.  69. 205.   2.   2.]
#  [106.  74.  69.   2.   3.]
#  [127. 106.  74.   3.   3.]
#  [174. 127. 106.   3.   3.]
#  [ 75. 174. 127.   3.   1.]
#  [122.  75. 174.   1.   1.]
#  [204. 122.  75.   1.   1.]
#  [ 76. 204. 122.   1.   4.]
#  [ 41.  76. 204.   4.   4.]
#  [ 99.  41.  76.   4.   4.]
#  [107.  99.  41.   4.   2.]
#  [168. 107.  99.   2.   2.]
#  [ 88. 168. 107.   2.   2.]
#  [101.  88. 168.   2.   3.]
#  [357. 101.  88.   3.   3.]]

# %%
Y = s.values[3:-3] 
Y
# Out:
# array([ 74, 161, 177,  60,  87, 281, 194,  91, 191, 137,  72, 163, 176,
#        205,  69,  74, 106, 127, 174,  75, 122, 204,  76,  41,  99, 107,
#        168,  88, 101, 357, 114], dtype=int64)

# %%
clf = linear_model.RidgeCV(alphas=[0.1, 1.0, 10.0])  
clf.fit(X, Y) 
RidgeCV(alphas=[0.1, 1.0, 10.0], cv=None, fit_intercept=True, scoring=None, normalize=False)
predictionProb = model.predict_proba( dataTest )
